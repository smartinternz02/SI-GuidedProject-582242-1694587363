# %% [markdown]
# # ASSIGNMENT 2
# 08-09-2004

# %% [raw]
# NAME: SWETHA JP
#     REG NO: 21BLC1407

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  1.Load the data set

# %%
data=pd.read_csv("car_crashes.csv")
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.pairplot(data)

# %% [raw]
# inference:
#     pairplot gives the relationship between the variables in the dataset

# %%
sns.distplot(data.ins_losses)
# Out:
# C:\Users\J.P.Swetha\AppData\Local\Temp\ipykernel_70300\1689502277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.ins_losses)
# <Axes: xlabel='ins_losses', ylabel='Density'>

# %% [raw]
# inference:
#     it is negatively skewed..its peak tendency is at 1.42
#     it shows great variability.

# %%
x=data['alcohol']
y=data['speeding']
plt.scatter(x,y,color='blue')
plt.xlabel('alcohol')
plt.ylabel('speed')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# inference:
#     from the plot we camn say that when the alcohol consumping is high they drive in high speed

# %%
df=sns.load_dataset('car_crashes')

# %%
df.head(3)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ

# %%
sns.scatterplot(x='speeding',y='alcohol',data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
sns.scatterplot(x='speeding',y='not_distracted',data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %% [raw]
# inference:
#     from the above graoh we can see thta...if the speeding increases the drivers wont get distarcted.

# %%
sns.distplot(df["alcohol"])
# Out:
# C:\Users\J.P.Swetha\AppData\Local\Temp\ipykernel_70300\3201832786.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
plt.bar(x,y,width=0.1)
plt.xlabel("alcohol")
plt.ylabel("speeding")
# Out:
# Text(0, 0.5, 'speeding')

# %%
p=data["ins_premium"]
l=data["ins_losses"]
plt.hist(p)
plt.show()
plt.xlabel("ins_premium")
# Out:
# Text(0.5, 0, 'ins_premium')
